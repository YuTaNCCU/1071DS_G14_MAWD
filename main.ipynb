# %%
import tabu_search_functions
# Out:
# rule1:  55.24691358024691
# [2, 1, 2, 2, 2, 3, 3, 2, 3, 2, 2, 2, 2, 2, 0]
# 68 60.0 75.0
# rule2:  89.33333333333333
# rule3:  30.424242424242426
# rule4:  36.0
# 56.320426487093144
# ['306008001', '307942001', '', '306525001', '356808001', '', '307851001', '306736001', '', '307867001', '307873001', '', '356019001', '356388001', '', '356387001', '356395001', '', '356813001', '306016022', '', '306000001', '307034001', '', '306737001', '356389001', '', '307857001', '306016002', '', '356425001', '307901001', '', '356461001', '307035001', '', '356822001', '307932001', '', '306016012', '356564001', '', '307870001', '306050011', '']
# Initial Solution:
# ...

# %%
TabuSearchResult = tabu_search_functions.TabuSearch()
# Out:
# Initial Solution:
#  ['306000001', '', '306008001', '', '', '306016002', '356425001', '', '306016012', '307873001', '', '307867001', '307942001', '', '307870001', '306016022', '307857001', '306050011', '356387001', '356388001', '307851001', '306525001', '', '307035001', '306736001', '356395001', '307034001', '356461001', '', '306737001', '307932001', '', '356822001', '', '356389001', '356019001', '356564001', '', '307901001', '356813001', '', '356808001', '', '', '']
# rule1:  64.44444444444446
# [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# 60 60.0 75.0
# rule2:  100.0
# rule3:  40.727272727272734
# rule4:  33.33333333333333
# Initial Obj. Val.:  64.99797979797981
# rule1:  64.44444444444446
# [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 2, 1, 2, 2]
# 62 60.0 75.0
# rule2:  97.33333333333333
# rule3:  40.12121212121212
# rule4:  33.33333333333333
# rule1:  59.01234567901235
# [2, 2, 3, 2, 1, 2, 2, 2, 2, 2, 2, 3, 1, 2, 2]
# 64 60.0 75.0
# rule2:  94.66666666666667
# rule3:  38.30303030303032
# ...
